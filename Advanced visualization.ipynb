# %%
#Category type in dataframe
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lilyan Ahmetoglu\\Desktop\\Python_for_datascience'

# %%
movies = pd.read_csv('P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','RottenTomatoesRatings', 'AudienceRating','BudgetMillion','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoesRatings  AudienceRating  \
# 0  (500) Days of Summer      Comedy                     87              81
# 1            10,000 B.C.  Adventure                      9              44
# 2             12 Rounds      Action                     30              52
# 3              127 Hours  Adventure                     93              84
# 4              17 Again      Comedy                     55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                     559 non-null object
# Genre                    559 non-null object
# RottenTomatoesRatings    559 non-null int64
# AudienceRating           559 non-null int64
# BudgetMillion            559 non-null int64
# Year                     559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        RottenTomatoesRatings  AudienceRating  BudgetMillion         Year
# count             559.000000      559.000000     559.000000   559.000000
# mean               47.309481       58.744186      50.236136  2009.152057
# std                26.413091       16.826887      48.731817     1.362632
# min                 0.000000        0.000000       0.000000  2007.000000
# 25%                25.000000       47.000000      20.000000  2008.000000
# 50%                46.000000       58.000000      35.000000  2009.000000
# 75%                70.000000       72.000000      65.000000  2010.000000
# max                97.000000       96.000000     300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                     559 non-null category
# Genre                    559 non-null object
# RottenTomatoesRatings    559 non-null int64
# AudienceRating           559 non-null int64
# BudgetMillion            559 non-null int64
# Year                     559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                     559 non-null category
# Genre                    559 non-null category
# RottenTomatoesRatings    559 non-null int64
# AudienceRating           559 non-null int64
# BudgetMillion            559 non-null int64
# Year                     559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.describe() # we notice that the year is not numerical column anymore it is catergorical
# Out:
#        RottenTomatoesRatings  AudienceRating  BudgetMillion
# count             559.000000      559.000000     559.000000
# mean               47.309481       58.744186      50.236136
# std                26.413091       16.826887      48.731817
# min                 0.000000        0.000000       0.000000
# 25%                25.000000       47.000000      20.000000
# 50%                46.000000       58.000000      35.000000
# 75%                70.000000       72.000000      65.000000
# max                97.000000       96.000000     300.000000

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
#jointPlot

# %%
j = sns.jointplot(data=movies, x='RottenTomatoesRatings', y='AudienceRating')

# %%
j = sns.jointplot(data=movies, x='RottenTomatoesRatings', y='AudienceRating',kind='hex') 
#hex is interesting vis type because it is shwoing clusturing of data

# %%
j = sns.jointplot(data=movies, x='RottenTomatoesRatings', y='RottenTomatoesRatings',kind='hex')

# %% [markdown]
# ---

# %%
#Histogram

# %%
m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
m2 = sns.distplot(movies.RottenTomatoesRatings, bins=15)
sns.set_style ("whitegrid") #adding grid to the graph

# %%
# let's check the distibution graph without seaborn library 
# we already know that the seaborn library has been belt over the pyplot so we can use pyplot for visualization 
n1= plt.hist(movies.RottenTomatoesRatings, bins=15)

# %%
# stacked Histograms

# %%
Filter1= movies.Genre == 'Drama'
Filter3= movies.Genre == 'Thriller'
Filter2= movies.Genre == 'Action'

plt.hist(movies.BudgetMillion[Filter2],bins=15)
plt.hist(movies.BudgetMillion[Filter1],bins=15)
plt.hist(movies.BudgetMillion[Filter3],bins=15)
plt.show()

# %%
plt.hist([movies.BudgetMillion[Filter2],\
          movies.BudgetMillion[Filter1],\
          movies.BudgetMillion[Filter3]],\
         bins=15,stacked=True)
plt.show()

# %%
# LET'S GIT rid of monkey code by using loop

# %%
gList = movies.Genre.cat.categories

# %%
 gList # list of uniqe genre
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
List1 = list()
myLabels= list()
for gen in gList:
    List1.append(movies.BudgetMillion[movies.Genre == gen]) # we will add to list new genre each time
    myLabels.append(gen)
h=plt.hist(List1,bins=30,stacked=True,rwidth=1,label = myLabels)
plt.legend()
plt.show()

# %%
#KDE plot

# %%
vis1= sns.lmplot(data=movies , x="RottenTomatoesRatings",y="AudienceRating",fit_reg=False,hue="Genre",size=7,aspect=1)

# %%
k1= sns.kdeplot(movies.RottenTomatoesRatings, movies.AudienceRating) # showing the density of the data

# %%
k1= sns.kdeplot(movies.RottenTomatoesRatings, movies.AudienceRating,shade=True,shade_lowest=False,cmap="Reds") # look like heat map

# %%
k1b= sns.kdeplot(movies.RottenTomatoesRatings, movies.AudienceRating,shade_lowest=False,cmap="Reds") # see the outlines

# %%
# i would like to have both plot at the same time so will run both line the same time
k1= sns.kdeplot(movies.RottenTomatoesRatings,\
                movies.AudienceRating,\
                shade=True,\
                shade_lowest=False,\
                cmap="Reds") # look like heat map 
k1b= sns.kdeplot(movies.RottenTomatoesRatings,\
                 movies.AudienceRating,\
                 shade_lowest=False,\
                 cmap="Reds") # see the outlines

# %%
#working with subPlots
sns.set_style("dark")
k1= sns.kdeplot(movies.BudgetMillion,movies.AudienceRating)

# %%
k1= sns.kdeplot(movies.BudgetMillion,movies.RottenTomatoesRatings)

# %%
f, ax = plt.subplots(1,2,figsize=(12,6))

# %%
f, axes = plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True) #sharex and sharey in order to set same axes to both figures
k1= sns.kdeplot(movies.BudgetMillion,movies.AudienceRating ,ax=axes[0])
k2= sns.kdeplot(movies.BudgetMillion,movies.RottenTomatoesRatings,ax=axes[1])
k1.set(xlim=(-20,160))
#k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#violinPlot

# %%
w= sns.boxplot(data= movies, x="Genre" , y="RottenTomatoesRatings")

# %%
z= sns.violinplot(data= movies, x="Genre" , y="RottenTomatoesRatings") 
# the width tells you the number of points fall down here

# %%
w= sns.boxplot(data= movies[movies.Genre=="Drama"], x="Year" , y="RottenTomatoesRatings")

# %%
w= sns.violinplot(data= movies[movies.Genre=="Drama"], x="Year" , y="RottenTomatoesRatings")

# %% [markdown]
# ## Facet Grid
# ---

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year',hue="Genre") # we created grid to populate our figure in it

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year',hue="Genre") # we created grid to populate our figure in it
g = g.map(plt.scatter,'RottenTomatoesRatings','AudienceRating') #takes func , *arguments and it is used to populate our plot inside our facetgrid
#no need to specify the dataset name inside map fun because it is already has been specified in FacetGrid fun

# %%
# we can pupolate with any type of chart

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year',hue="Genre") # we created grid to populate our figure in it
g = g.map(plt.hist,'BudgetMillion')

# %%
#back to scatter plot
g = sns.FacetGrid(movies, row='Genre', col='Year',hue="Genre")
kws = dict(s=50, linewidth = 0.5, edgecolor='black') # dictionary with keywords in order to make the plot more clear
g = g.map(plt.scatter,'RottenTomatoesRatings','AudienceRating',**kws)

# %% [markdown]
# ## coordinates and diagonals
# ---

# %%
#controlling axis and adding diagonals
g = sns.FacetGrid(movies, row='Genre', col='Year',hue="Genre")
kws = dict(s=50, linewidth = 0.5, edgecolor='black') # dictionary with keywords in order to make the plot more clear
g = g.map(plt.scatter,'RottenTomatoesRatings','AudienceRating',**kws)
g.set(xlim=(0,100), ylim=(0,100)) #setting axis from 0 to 100 each

# now we need to add diagonal to each one of the plots
for ax in g.axes.flat: #check theses functions from shift+tab
    ax.plot((0,100),(0,100), c="gray",ls="--")
# each dote is represnting a movie

g.add_legend()

# %% [markdown]
# ## build dashboard
# ---

# %%
#using subplot function we will create the dashboard
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.set_style('darkgrid') 
f, axes = plt.subplots(2,2,figsize=(15,15))  
# you can add as much as you want od charts just add the sns plot code and add the axes as last argument
# we can add plot that is not belong to sns or same library  but the prosedure is different
# example of other plot we will simply do the following 
#axes[1,1].hist(movies.RottenTomatoesRatings,bins=15) 
#So instead of plt we will define axes location then call the plotting function

#fig 1
k1= sns.kdeplot(movies.BudgetMillion,movies.AudienceRating ,ax=axes[0,0])
#fig 2
k2= sns.kdeplot(movies.BudgetMillion,movies.RottenTomatoesRatings,ax=axes[0,1])
#fig 3
z= sns.violinplot(data= movies[movies.Genre=="Drama"], x="Year" , y="RottenTomatoesRatings",ax=axes[1,0])

# fig 4
k4= sns.kdeplot(movies.RottenTomatoesRatings,\
                movies.AudienceRating,\
                shade=True,\
                shade_lowest=False,\
                cmap="Reds",ax=axes[1,1]) # look like heat map 
k4b= sns.kdeplot(movies.RottenTomatoesRatings,\
                 movies.AudienceRating,\
                 cmap="Reds",ax=axes[1,1]) # see the outlines

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %% [markdown]
# ## styling dashoard
# ---

# %%
sns.set_style('dark', {"axes.facecolor":"black"}) #  because we don't have much choices for colors in seaborn so we have to
#pass a dictionary with the wanted color 
# we want to make all background as black
f, axes = plt.subplots(2,2,figsize=(15,15))  

#fig 1
k1= sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,\
                shade=True ,\
                shade_lowest=True,\
                 cmap="inferno",\
                ax=axes[0,0])
k1b= sns.kdeplot(movies.BudgetMillion,\
                 movies.AudienceRating,\
                 cmap="cool",ax=axes[0,0]) # see the outlines
#fig 2
k2= sns.kdeplot(movies.BudgetMillion,movies.RottenTomatoesRatings,\
                shade=True ,\
                shade_lowest=True,\
                cmap="inferno",\
                ax=axes[0,1])
k2b= sns.kdeplot(movies.BudgetMillion,\
                 movies.RottenTomatoesRatings,\
                 cmap="cool",ax=axes[0,1]) # see the outlines
#fig 3
z= sns.violinplot(data= movies[movies.Genre=="Drama"], x="Year" , y="RottenTomatoesRatings",ax=axes[1,0],\
                 palette='YlOrRd')

# fig 4
k4= sns.kdeplot(movies.RottenTomatoesRatings,\
                movies.AudienceRating,\
                shade=True,\
                shade_lowest=False,\
                cmap="Blues_r",ax=axes[1,1]) # look like heat map 
k4b= sns.kdeplot(movies.RottenTomatoesRatings,\
                 movies.AudienceRating,\
                 cmap="gist_gray_r",ax=axes[1,1]) # see the outlines

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]
